# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\Bipeen Malgundkar\OneDrive\Desktop\StudentPerformanceFactors.csv")

# %%
# Student Performance Analysis using Python

# %%
df.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Teacher_Quality Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# 0          Medium                         No            7               73
# 1          Medium                         No            8               59
# 2          Medium                        Yes            7               91
# 3          Medium                        Yes            8               98
# 4            High                        Yes            6               65
#
#   Motivation_Level Internet_Access  ...  Family_Income School_Type  \
# ...

# %%
df.shape
# Out:
# (6607, 21)

# %%
df.columns
# Out:
# Index(['Hours_Studied', 'Attendance', 'Parental_Involvement',
#        'Access_to_Resources', 'Teacher_Quality', 'Extracurricular_Activities',
#        'Sleep_Hours', 'Previous_Scores', 'Motivation_Level', 'Internet_Access',
#        'Tutoring_Sessions', 'Family_Income', 'School_Type', 'Peer_Influence',
#        'Physical_Activity', 'Learning_Disabilities',
#        'Parental_Education_Level', 'Distance_from_Home', 'Gender',
#        'Exam_Score', 'Performance_Category'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Hours_Studied                  int64
# Attendance                     int64
# Parental_Involvement          object
# Access_to_Resources           object
# Teacher_Quality               object
# Extracurricular_Activities    object
# Sleep_Hours                    int64
# Previous_Scores                int64
# Motivation_Level              object
# Internet_Access               object
# Tutoring_Sessions              int64
# Family_Income                 object
# School_Type                   object
# Peer_Influence                object
# Physical_Activity              int64
# Learning_Disabilities         object
# Parental_Education_Level      object
# Distance_from_Home            object
# Gender                        object
# Exam_Score                     int64
# Performance_Category          object
# dtype: object

# %%
## Dataset Overview

# %%
df.nlargest(5,'Exam_Score')
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 1525             27          98                  Low              Medium
# 94               18          89                 High              Medium
# 2425             23          83                 High                High
# 3579             14          90                 High                High
# 4192             28          90                  Low              Medium
#
#      Teacher_Quality Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# 1525            High                        Yes            6               93
# 94            Medium                        Yes            4               73
# 2425          Medium                        Yes            4               89
# 3579          Medium                        Yes            8               86
# 4192          Medium                        Yes            9               91
#
# ...

# %%
df.nlargest(5,'Attendance')
# Out:
#      Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 74               4         100                 High                High
# 106             31         100               Medium              Medium
# 222             24         100                 High                High
# 230             16         100                 High                 Low
# 413             28         100                 High                 Low
#
#     Teacher_Quality Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# 74             High                        Yes            8               60
# 106            High                         No            7               59
# 222          Medium                        Yes            6               86
# 230          Medium                        Yes            8               63
# 413          Medium                        Yes            6               72
#
# ...

# %%
## Top Performing Students

# %%
df[
(df['Hours_Studied']<5)&(df['Exam_Score']>80)]
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 4779              1          88               Medium                High
#
#      Teacher_Quality Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# 4779          Medium                        Yes            4               72
#
#      Motivation_Level Internet_Access  ...  Family_Income School_Type  \
# 4779             High             Yes  ...         Medium     Private
#
#      Peer_Influence Physical_Activity  Learning_Disabilities  \
# 4779       Negative                 2                     No
#
#      Parental_Education_Level Distance_from_Home Gender Exam_Score  \
# 4779                  College               Near   Male         92
#
#       Performance_Category
# 4779             Excellent
#
# [1 rows x 21 columns]

# %%
df[(df['Motivation_Level']=='High')&(df['Attendance']<70)]
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 25               21          62                 High                 Low
# 80               19          69               Medium                High
# 83               17          67               Medium              Medium
# 99               19          67                  Low              Medium
# 104              19          67               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6551             27          68                  Low                 Low
# 6552             22          65                  Low              Medium
# 6573             17          64               Medium              Medium
# 6583             11          67               Medium                High
# 6587             18          68                 High                High
#
#      Teacher_Quality Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
## Gender Analysis

# %%
df[df['Gender']=='Female']['Exam_Score'].max()
# Out:
# np.int64(101)

# %%
df[df['Gender']=='Male']['Exam_Score'].max()
# Out:
# np.int64(99)

# %%
## Motivation and Performance Analysis

# %%
df[(df['Motivation_Level']=='High') & (df['Performance_Category']=='Excellent')]
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 217              19          70               Medium                 Low
# 560              22          71                  Low                High
# 637              20          65               Medium                 Low
# 2595              7          69               Medium                High
# 2904             11          62                 High              Medium
# 3364             16          76               Medium                High
# 3924             18          87                  Low                 Low
# 4355             24          70               Medium                High
# 4405             25          98               Medium              Medium
# 4666             16          71                  Low                 Low
# 4779              1          88               Medium                High
# 5989             18          61               Medium                 Low
# ...

# %%
## Performance Category Distribution

# %%
df['Performance_Category'].value_counts().plot(kind='bar')
plt.title('Performance Category Distribution')
plt.xlabel('Performance Category')
plt.ylabel('Number of Students')
plt.show()

# %%
## Gender Distribution

# %%
df['Gender'].value_counts().plot(kind='bar')
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Number of Students')
plt.show()

# %%
## Study Hours Analysis

# %%
df.plot(x='Hours_Studied', y='Exam_Score',kind='scatter')
plt.title('Hours Studied vs Exam Score')
plt.xlabel('Hours_Studied')
plt.ylabel('Exam_Score')
plt.show()

# %%
Distribution of Exam Score

# %%
df['Exam_Score'].plot(kind='hist',bins=10)
plt.title('Distribution of Exam Score')
plt.xlabel('Exam_Score')
plt.show()
